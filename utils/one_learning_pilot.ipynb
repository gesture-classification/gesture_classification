# %%
# Установка версий программных пакетов
#!pip install -qr ../requirements.txt

# Импортируем библиотеки
import numpy as np
#import pandas as pd

# графические библиотеки
from matplotlib import pyplot as plt
# %matplotlib widget
import os

# Зафиксируем PYTHONHASHSEED для воспроиизводимости результатов обучения модели
seed_value = 0
os.environ['PYTHONHASHSEED'] = str(seed_value)

# Логгирование процесса
from comet_ml import Experiment

# библиотеки машинного обучения
import tensorflow as tf
import random

# библиотека взаимодействия с интерпретатором
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")


# Скрытие хода обучения модели,который загромождает ноутбук
from IPython.display import clear_output

# Библиотека вызова функций, специально разработанных для данного ноутбука
sys.path.insert(1, '../')
from utils.functions import config_reader, f1, callbacks, reset_random_seeds
from utils.data_reader import DataReader
from utils.data_loader import DataLoader
from utils import figures

# Импортируем константы из файла config
path_to_config='../config/data_config.json'
config = config_reader(path_to_config)

# Импортируем модели
from models.models import SimpleRNN_Model, LSTM_Model

# credentials = config_reader('../config/credentials.json')
# experiment = Experiment(
#     api_key = credentials.api_key, 
#     project_name = credentials.project_name,
#     workspace = credentials.workspace,
# );  
# experiment.set_name('model') # имя эксперимента

# константы и глобальные параметры данных
# Все исходные файлы размещены в папке data
PATH = config.PATH

# Папка для сохранения весов лучшей модели при обучении (исп-ся в ModelCheckpoint в функции callbacks)
PATH_TEMP_MODEL = config.PATH_TEMP_MODEL

if not os.path.exists(PATH_TEMP_MODEL):
    os.mkdir(PATH_TEMP_MODEL)    

# Папка для сохранения обученных моделей для последующего предсказания
PATH_FOR_MODEL = config.PATH_FOR_MODEL

if not os.path.exists(PATH_FOR_MODEL):
    os.mkdir(PATH_FOR_MODEL)

# 1. Установим начальное значение для генератора случайных чисел в Python
random.seed(seed_value)

# 2. Установим начальное значение для генератора случайных чисел в Numpy
np.random.seed(seed_value)

# 3. Установим начальное значение для генератора случайных чисел в tensorflow 
tf.random.set_seed(seed_value)

# 4. Конфигурация Tenzorflow
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

# Словарь для последующей агрегации данных. Изначально прописаны названия файлов в архиве
mounts = config.mounts.toDict()

print('Imports Done!', sep='\n\n')

### Read Data
#i = input('Enter pilot number, ex: 1, 2, 3, etc.')
i = str(2)

mounts[int(i)] = mounts.pop(i)
i = int(i)

# Загружаем данные в словарь с помощью DataLoader
data_for_nn = DataLoader(i, config)
mounts[i]['X_train_nn'] = data_for_nn.X_train_nn
mounts[i]['y_train_nn'] = data_for_nn.y_train_nn
mounts[i]['X_test_dataset'] = DataReader(
    os.path.join(config.PATH, config.mounts[str(i)].path_X_test_dataset)).data

print('Read Data Done!', sep='\n\n')

### Load and train SimpleRNN
X_train_nn = mounts[i]['X_train_nn']
y_train_nn = mounts[i]['y_train_nn']

# Создаем пустой лист для накопления данных с последующей корректировкой y_train
mounts[i]['y_trn_nn_ch_list'] = []

for splt_coef in range(10, 100, config.simpleRNN_delta_coef_splt): 
    
    # кол-во разных тренировок зависит от числа разбиений.
    val_splt_coef = splt_coef/100

    tf.keras.backend.clear_session()
    reset_random_seeds(seed_value) # сброс и задание random seed

    model = SimpleRNN_Model(X_train_nn, y_train_nn, 
                            units=config.simpleRNN_units).build_model()
    
    model = tf.keras.models.clone_model(model)
    
    model.compile(
        loss="mean_squared_error", 
        metrics=[f1], 
        optimizer='Adam', # по умолчанию learning rate=10e-3
    )

    history = model.fit(
        X_train_nn, 
        y_train_nn, 
        validation_split=val_splt_coef, 
        callbacks=callbacks(
            reduce_patience=config.reduce_patience, 
            stop_patience=config.stop_patience, 
            num_train=i,
            
            PATH_BEST_MODEL=config.PATH_TEMP_MODEL,
            monitor=config.ModelCheckpoint.monitor, 
            verbose=config.ModelCheckpoint.verbose, 
            mode=config.ModelCheckpoint.mode, 
            save_best_only=config.ModelCheckpoint.save_best_only,

            restore_best_weights=config.EarlyStopping.restore_best_weights,
            
            factor=config.ReduceLROnPlateau.factor, 
            min_lr=config.lr / config.ReduceLROnPlateau.min_lr_coeff),  # остальные параметры - смотри в functions.py
        epochs=config.simpleRNN_epochs, 
        verbose=config.simpleRNN_verbose
    )
    
    #experiment.log_parameter("callbacks", callbacks) # логгируем  callbacks
    
    y_pred_train_nn = model.predict(X_train_nn)  #m.predict(X_train_nn) 
    print(y_pred_train_nn.shape)
    
    #mounts[i]['model'] = model # модели сохранять не нужно
    
    mounts[i]['y_trn_nn_ch_list'].append(y_pred_train_nn)

# создаём переменную для записи среднего значения предсказаний
y_pred_train_nn = np.mean(mounts[i]['y_trn_nn_ch_list'], axis=0).argmax(axis=-1)
    
# сохраняем в словарь
mounts[i]['y_pred_train_nn'] = tf.keras.utils.to_categorical(y_pred_train_nn)

# Визуализируем ход обучения модели #1
#figures.plot_history(history, plot_counter='2-3')
#experiment.log_figure(figure_name='fig_2-3') # логгируем график


# # Отображение предсказания моделью SimpleRNN
# Pilot_id=3
# y_pred_train_nn = mount['y_pred_train_nn']
# y_pred_train_nn_mean = np.mean(x_trn_pred_dict[Pilot_id], axis=0)

# figures.get_gesture_prediction_plot(
#     Pilot_id=3, 
#     i=5, 
#     mounts=mounts, 
#     y_pred_train_nn_mean=y_pred_train_nn_mean, 
#     plot_counter='2-4'
# )

# #experiment.log_figure(figure_name='fig_2-4') # логгируем график

print('Load and train SimpleRNN Done!', sep='\n\n')

### Load and train LSTM
tf.keras.backend.clear_session()
reset_random_seeds(seed_value)
y_pred_train_nn = mounts[i]['y_pred_train_nn']

model_lstm = LSTM_Model(X_train_nn, y_pred_train_nn, 
                        lstm_units=config.lstm_units).build_model()    

model_lstm.compile(
    loss="categorical_crossentropy", 
    metrics=[f1], 
    optimizer='Adam', # по умолчанию learning rate=10e-3
)

# m_lstm = tf.keras.models.clone_model(model_lstm)

history2 = model_lstm.fit(
    X_train_nn,
    y_pred_train_nn,
    validation_split=config.lstm_val_splt,
    epochs=config.lstm_epochs,      
    verbose=config.lstm_verbose,
    callbacks=callbacks(
            reduce_patience=config.reduce_patience, 
            stop_patience=config.stop_patience, 
            
            PATH_BEST_MODEL=config.PATH_TEMP_MODEL,
            monitor=config.ModelCheckpoint.monitor, 
            verbose=config.ModelCheckpoint.verbose, 
            mode=config.ModelCheckpoint.mode, 
            save_best_only=config.ModelCheckpoint.save_best_only,

            restore_best_weights=config.EarlyStopping.restore_best_weights,
            
            factor=config.ReduceLROnPlateau.factor, 
            min_lr=config.lr / config.ReduceLROnPlateau.min_lr_coeff,
            num_train=i)  # остальные параметры - смотри в functions.py
    )

mounts[i]['history2'] = history2

mounts[i]['model_lstm'] = model_lstm

print('Load and train SimpleRNN Done!')

# сохранение обученной модели в папке по пути PATH_FOR_MODEL
model_lstm.save(os.path.join(PATH_FOR_MODEL, 'model_lstm_' + str(i) + '.h5'), save_format='h5')

print('Model LSTM saved!', sep='\n\n')

# Визуализируем ход обучения модели #2
#figures.plot_history(history2, plot_counter='2-5') 
#experiment.log_figure(figure_name='fig_2-5') # логгируем график

# # Визуализируем предскание жеста моделью
# Pilot_id=3 # номер пилота

# y_pred_train_nn_mean = mounts[Pilot_id]['y_pred_train_lstm']

# figures.get_gesture_prediction_plot(
#     Pilot_id=3, # номер пилота
#     i=18, # номер наблюдения
#     y_pred_train_nn_mean=y_pred_train_nn_mean, 
#     mounts=mounts, # словарь
#     plot_counter='2-6')

# #experiment.log_figure(figure_name='fig_2-6') # логгируем график

# Заканчиваем сессию логгирования эксперимента
#experiment.end()

# отображаем результат обучения
#experiment.display()
# Out:
# Imports Done!
# Creating RawArray with float64 data, n_channels=50, n_times=23202
#     Range : 0 ... 23201 =      0.000 ...   765.633 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=23202
#     Range : 0 ... 23201 =      0.000 ...   765.633 secs
# Ready.
# Not setting metadata
# 264 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 264 events and 107 original time points ...
# 1 bad epochs dropped
# Read Data Done!
# input_shape = (None, 50) | output_units = 5
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, 50)]        0
#
#  batch_normalization (BatchN  (None, None, 50)         200
#  ormalization)
#
#  simple_rnn (SimpleRNN)      (None, None, 100)         15100
#
#  batch_normalization_1 (Batc  (None, None, 100)        400
#  hNormalization)
#
#  dense (Dense)               (None, None, 5)           505
#
# =================================================================
# Total params: 16,205
# Trainable params: 15,905
# Non-trainable params: 300
# _________________________________________________________________
# Epoch 1/20
# 8/8 [==============================] - ETA: 0s - loss: 0.2835 - f1: 0.3126
# Epoch 1: val_f1 improved from -inf to 0.40518, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 8/8 [==============================] - 7s 227ms/step - loss: 0.2835 - f1: 0.3126 - val_loss: 0.2733 - val_f1: 0.4052 - lr: 0.0010
# Epoch 2/20
# 8/8 [==============================] - ETA: 0s - loss: 0.2428 - f1: 0.4003
# Epoch 2: val_f1 improved from 0.40518 to 0.41144, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 8/8 [==============================] - 1s 114ms/step - loss: 0.2428 - f1: 0.4003 - val_loss: 0.2638 - val_f1: 0.4114 - lr: 0.0010
# Epoch 3/20
# 8/8 [==============================] - ETA: 0s - loss: 0.2268 - f1: 0.4453
# Epoch 3: val_f1 did not improve from 0.41144
# 8/8 [==============================] - 1s 103ms/step - loss: 0.2268 - f1: 0.4453 - val_loss: 0.2637 - val_f1: 0.4075 - lr: 0.0010
# Epoch 4/20
# 8/8 [==============================] - ETA: 0s - loss: 0.2137 - f1: 0.4785
# Epoch 4: val_f1 improved from 0.41144 to 0.41888, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 8/8 [==============================] - 1s 141ms/step - loss: 0.2137 - f1: 0.4785 - val_loss: 0.2521 - val_f1: 0.4189 - lr: 0.0010
# Epoch 5/20
# 8/8 [==============================] - ETA: 0s - loss: 0.2033 - f1: 0.4970
# Epoch 5: val_f1 improved from 0.41888 to 0.45032, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 8/8 [==============================] - 1s 113ms/step - loss: 0.2033 - f1: 0.4970 - val_loss: 0.2423 - val_f1: 0.4503 - lr: 0.0010
# Epoch 6/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1949 - f1: 0.5225
# Epoch 6: val_f1 improved from 0.45032 to 0.45347, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1949 - f1: 0.5225 - val_loss: 0.2301 - val_f1: 0.4535 - lr: 0.0010
# Epoch 7/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1849 - f1: 0.5485
# Epoch 7: val_f1 improved from 0.45347 to 0.48625, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1849 - f1: 0.5485 - val_loss: 0.2216 - val_f1: 0.4863 - lr: 0.0010
# Epoch 8/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1773 - f1: 0.5647
# Epoch 8: val_f1 did not improve from 0.48625
# 8/8 [==============================] - 1s 96ms/step - loss: 0.1773 - f1: 0.5647 - val_loss: 0.2208 - val_f1: 0.4729 - lr: 0.0010
# Epoch 9/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1690 - f1: 0.5702
# Epoch 9: val_f1 did not improve from 0.48625
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1690 - f1: 0.5702 - val_loss: 0.2256 - val_f1: 0.4471 - lr: 0.0010
# Epoch 10/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1610 - f1: 0.5860
# Epoch 10: val_f1 did not improve from 0.48625
# 8/8 [==============================] - 1s 96ms/step - loss: 0.1610 - f1: 0.5860 - val_loss: 0.2265 - val_f1: 0.4363 - lr: 0.0010
# Epoch 11/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1543 - f1: 0.6043
# Epoch 11: val_f1 did not improve from 0.48625
# 8/8 [==============================] - 1s 127ms/step - loss: 0.1543 - f1: 0.6043 - val_loss: 0.2293 - val_f1: 0.4214 - lr: 0.0010
# Epoch 12/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1477 - f1: 0.6114
# Epoch 12: val_f1 did not improve from 0.48625
# 8/8 [==============================] - 1s 98ms/step - loss: 0.1477 - f1: 0.6114 - val_loss: 0.2245 - val_f1: 0.4312 - lr: 0.0010
# Epoch 13/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1414 - f1: 0.6244
# Epoch 13: val_f1 did not improve from 0.48625
# 8/8 [==============================] - 1s 90ms/step - loss: 0.1414 - f1: 0.6244 - val_loss: 0.2290 - val_f1: 0.4199 - lr: 0.0010
# Epoch 14/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1333 - f1: 0.6435
# Epoch 14: val_f1 did not improve from 0.48625
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1333 - f1: 0.6435 - val_loss: 0.2214 - val_f1: 0.4287 - lr: 0.0010
# Epoch 15/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1288 - f1: 0.6348
# Epoch 15: val_f1 did not improve from 0.48625
# 8/8 [==============================] - 1s 95ms/step - loss: 0.1288 - f1: 0.6348 - val_loss: 0.2157 - val_f1: 0.4309 - lr: 0.0010
# Epoch 16/20
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1246 - f1: 0.6428
# Epoch 16: val_f1 did not improve from 0.48625
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1250 - f1: 0.6406 - val_loss: 0.2099 - val_f1: 0.4335 - lr: 0.0010
# Epoch 17/20
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1208 - f1: 0.6445
# Epoch 17: val_f1 did not improve from 0.48625
# 8/8 [==============================] - 1s 86ms/step - loss: 0.1216 - f1: 0.6345 - val_loss: 0.2013 - val_f1: 0.4434 - lr: 0.0010
# Epoch 18/20
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1167 - f1: 0.6564
# Epoch 18: val_f1 did not improve from 0.48625
# 8/8 [==============================] - 1s 90ms/step - loss: 0.1170 - f1: 0.6511 - val_loss: 0.1918 - val_f1: 0.4467 - lr: 0.0010
# Epoch 19/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1130 - f1: 0.6550
# Epoch 19: val_f1 did not improve from 0.48625
# 8/8 [==============================] - 1s 98ms/step - loss: 0.1130 - f1: 0.6550 - val_loss: 0.1781 - val_f1: 0.4779 - lr: 0.0010
# Epoch 20/20
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1109 - f1: 0.6505
# Epoch 20: val_f1 did not improve from 0.48625
# 8/8 [==============================] - 1s 87ms/step - loss: 0.1101 - f1: 0.6633 - val_loss: 0.1714 - val_f1: 0.4853 - lr: 0.0010
# 9/9 [==============================] - 1s 28ms/step
# (263, 107, 5)
# input_shape = (None, 50) | output_units = 5
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, 50)]        0
#
#  batch_normalization (BatchN  (None, None, 50)         200
#  ormalization)
#
#  simple_rnn (SimpleRNN)      (None, None, 100)         15100
#
#  batch_normalization_1 (Batc  (None, None, 100)        400
#  hNormalization)
#
#  dense (Dense)               (None, None, 5)           505
#
# =================================================================
# Total params: 16,205
# Trainable params: 15,905
# Non-trainable params: 300
# _________________________________________________________________
# Epoch 1/20
# 6/6 [==============================] - ETA: 0s - loss: 0.2870 - f1: 0.3120
# Epoch 1: val_f1 improved from -inf to 0.37843, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 6/6 [==============================] - 7s 300ms/step - loss: 0.2870 - f1: 0.3120 - val_loss: 0.2882 - val_f1: 0.3784 - lr: 0.0010
# Epoch 2/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2484 - f1: 0.3891
# Epoch 2: val_f1 did not improve from 0.37843
# 6/6 [==============================] - 1s 105ms/step - loss: 0.2488 - f1: 0.3821 - val_loss: 0.2748 - val_f1: 0.3752 - lr: 0.0010
# Epoch 3/20
# 6/6 [==============================] - ETA: 0s - loss: 0.2321 - f1: 0.4380
# Epoch 3: val_f1 improved from 0.37843 to 0.38110, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 6/6 [==============================] - 1s 171ms/step - loss: 0.2321 - f1: 0.4380 - val_loss: 0.2776 - val_f1: 0.3811 - lr: 0.0010
# Epoch 4/20
# 6/6 [==============================] - ETA: 0s - loss: 0.2206 - f1: 0.4704
# Epoch 4: val_f1 improved from 0.38110 to 0.39107, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 6/6 [==============================] - 1s 147ms/step - loss: 0.2206 - f1: 0.4704 - val_loss: 0.2801 - val_f1: 0.3911 - lr: 0.0010
# Epoch 5/20
# 6/6 [==============================] - ETA: 0s - loss: 0.2110 - f1: 0.4968
# Epoch 5: val_f1 improved from 0.39107 to 0.40154, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 6/6 [==============================] - 1s 134ms/step - loss: 0.2110 - f1: 0.4968 - val_loss: 0.2744 - val_f1: 0.4015 - lr: 0.0010
# Epoch 6/20
# 6/6 [==============================] - ETA: 0s - loss: 0.2023 - f1: 0.5093
# Epoch 6: val_f1 improved from 0.40154 to 0.41234, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 6/6 [==============================] - 1s 133ms/step - loss: 0.2023 - f1: 0.5093 - val_loss: 0.2640 - val_f1: 0.4123 - lr: 0.0010
# Epoch 7/20
# 6/6 [==============================] - ETA: 0s - loss: 0.1958 - f1: 0.5283
# Epoch 7: val_f1 improved from 0.41234 to 0.42089, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 6/6 [==============================] - 1s 139ms/step - loss: 0.1958 - f1: 0.5283 - val_loss: 0.2547 - val_f1: 0.4209 - lr: 0.0010
# Epoch 8/20
# 6/6 [==============================] - ETA: 0s - loss: 0.1891 - f1: 0.5380
# Epoch 8: val_f1 improved from 0.42089 to 0.42769, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 6/6 [==============================] - 1s 135ms/step - loss: 0.1891 - f1: 0.5380 - val_loss: 0.2478 - val_f1: 0.4277 - lr: 0.0010
# Epoch 9/20
# 6/6 [==============================] - ETA: 0s - loss: 0.1811 - f1: 0.5682
# Epoch 9: val_f1 improved from 0.42769 to 0.42900, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 6/6 [==============================] - 1s 137ms/step - loss: 0.1811 - f1: 0.5682 - val_loss: 0.2432 - val_f1: 0.4290 - lr: 0.0010
# Epoch 10/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1742 - f1: 0.5862
# Epoch 10: val_f1 improved from 0.42900 to 0.43023, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 6/6 [==============================] - 1s 131ms/step - loss: 0.1750 - f1: 0.5772 - val_loss: 0.2372 - val_f1: 0.4302 - lr: 0.0010
# Epoch 11/20
# 6/6 [==============================] - ETA: 0s - loss: 0.1710 - f1: 0.5824
# Epoch 11: val_f1 did not improve from 0.43023
# 6/6 [==============================] - 1s 110ms/step - loss: 0.1710 - f1: 0.5824 - val_loss: 0.2339 - val_f1: 0.4267 - lr: 0.0010
# Epoch 12/20
# 6/6 [==============================] - ETA: 0s - loss: 0.1634 - f1: 0.6022
# Epoch 12: val_f1 did not improve from 0.43023
# 6/6 [==============================] - 1s 122ms/step - loss: 0.1634 - f1: 0.6022 - val_loss: 0.2294 - val_f1: 0.4228 - lr: 0.0010
# Epoch 13/20
# 6/6 [==============================] - ETA: 0s - loss: 0.1576 - f1: 0.6078
# Epoch 13: val_f1 did not improve from 0.43023
# 6/6 [==============================] - 1s 167ms/step - loss: 0.1576 - f1: 0.6078 - val_loss: 0.2238 - val_f1: 0.4279 - lr: 0.0010
# Epoch 14/20
# 6/6 [==============================] - ETA: 0s - loss: 0.1516 - f1: 0.6175
# Epoch 14: val_f1 improved from 0.43023 to 0.43336, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 6/6 [==============================] - 1s 176ms/step - loss: 0.1516 - f1: 0.6175 - val_loss: 0.2210 - val_f1: 0.4334 - lr: 0.0010
# Epoch 15/20
# 6/6 [==============================] - ETA: 0s - loss: 0.1460 - f1: 0.6230
# Epoch 15: val_f1 improved from 0.43336 to 0.44232, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 6/6 [==============================] - 1s 166ms/step - loss: 0.1460 - f1: 0.6230 - val_loss: 0.2168 - val_f1: 0.4423 - lr: 0.0010
# Epoch 16/20
# 6/6 [==============================] - ETA: 0s - loss: 0.1419 - f1: 0.6432
# Epoch 16: val_f1 improved from 0.44232 to 0.45511, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 6/6 [==============================] - 1s 158ms/step - loss: 0.1419 - f1: 0.6432 - val_loss: 0.2111 - val_f1: 0.4551 - lr: 0.0010
# Epoch 17/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1368 - f1: 0.6477
# Epoch 17: val_f1 did not improve from 0.45511
# 6/6 [==============================] - 1s 102ms/step - loss: 0.1366 - f1: 0.6514 - val_loss: 0.2127 - val_f1: 0.4459 - lr: 0.0010
# Epoch 18/20
# 6/6 [==============================] - ETA: 0s - loss: 0.1311 - f1: 0.6654
# Epoch 18: val_f1 did not improve from 0.45511
# 6/6 [==============================] - 1s 131ms/step - loss: 0.1311 - f1: 0.6654 - val_loss: 0.2111 - val_f1: 0.4545 - lr: 0.0010
# Epoch 19/20
# 6/6 [==============================] - ETA: 0s - loss: 0.1277 - f1: 0.6617
# Epoch 19: val_f1 did not improve from 0.45511
# 6/6 [==============================] - 1s 158ms/step - loss: 0.1277 - f1: 0.6617 - val_loss: 0.2111 - val_f1: 0.4536 - lr: 0.0010
# Epoch 20/20
# 6/6 [==============================] - ETA: 0s - loss: 0.1245 - f1: 0.6595
# Epoch 20: val_f1 did not improve from 0.45511
# 6/6 [==============================] - 1s 131ms/step - loss: 0.1245 - f1: 0.6595 - val_loss: 0.2061 - val_f1: 0.4544 - lr: 0.0010
# 9/9 [==============================] - 1s 29ms/step
# (263, 107, 5)
# input_shape = (None, 50) | output_units = 5
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, 50)]        0
#
#  batch_normalization (BatchN  (None, None, 50)         200
#  ormalization)
#
#  simple_rnn (SimpleRNN)      (None, None, 100)         15100
#
#  batch_normalization_1 (Batc  (None, None, 100)        400
#  hNormalization)
#
#  dense (Dense)               (None, None, 5)           505
#
# =================================================================
# Total params: 16,205
# Trainable params: 15,905
# Non-trainable params: 300
# _________________________________________________________________
# Epoch 1/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.3004 - f1: 0.2847
# Epoch 1: val_f1 improved from -inf to 0.38667, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 4/4 [==============================] - 5s 336ms/step - loss: 0.2976 - f1: 0.2968 - val_loss: 0.2992 - val_f1: 0.3867 - lr: 0.0010
# Epoch 2/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.2610 - f1: 0.3491
# Epoch 2: val_f1 did not improve from 0.38667
# 4/4 [==============================] - 0s 114ms/step - loss: 0.2600 - f1: 0.3578 - val_loss: 0.2834 - val_f1: 0.3743 - lr: 0.0010
# Epoch 3/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.2444 - f1: 0.4016
# Epoch 3: val_f1 did not improve from 0.38667
# 4/4 [==============================] - 0s 117ms/step - loss: 0.2443 - f1: 0.4034 - val_loss: 0.2805 - val_f1: 0.3709 - lr: 0.0010
# Epoch 4/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2344 - f1: 0.4208
# Epoch 4: val_f1 did not improve from 0.38667
# 4/4 [==============================] - 1s 170ms/step - loss: 0.2344 - f1: 0.4208 - val_loss: 0.2805 - val_f1: 0.3772 - lr: 0.0010
# Epoch 5/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.2237 - f1: 0.4670
# Epoch 5: val_f1 did not improve from 0.38667
# 4/4 [==============================] - 0s 119ms/step - loss: 0.2238 - f1: 0.4601 - val_loss: 0.2734 - val_f1: 0.3829 - lr: 0.0010
# Epoch 6/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.2168 - f1: 0.4804
# Epoch 6: val_f1 did not improve from 0.38667
# 4/4 [==============================] - 0s 116ms/step - loss: 0.2180 - f1: 0.4695 - val_loss: 0.2685 - val_f1: 0.3853 - lr: 0.0010
# Epoch 7/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.2105 - f1: 0.4969
# Epoch 7: val_f1 did not improve from 0.38667
# 4/4 [==============================] - 0s 121ms/step - loss: 0.2115 - f1: 0.4834 - val_loss: 0.2606 - val_f1: 0.3861 - lr: 0.0010
# Epoch 8/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.2054 - f1: 0.5085
# Epoch 8: val_f1 improved from 0.38667 to 0.40733, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 4/4 [==============================] - 0s 139ms/step - loss: 0.2056 - f1: 0.5091 - val_loss: 0.2484 - val_f1: 0.4073 - lr: 0.0010
# Epoch 9/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.1980 - f1: 0.5271
# Epoch 9: val_f1 improved from 0.40733 to 0.42764, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 4/4 [==============================] - 1s 145ms/step - loss: 0.1987 - f1: 0.5242 - val_loss: 0.2390 - val_f1: 0.4276 - lr: 0.0010
# Epoch 10/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.1939 - f1: 0.5358
# Epoch 10: val_f1 improved from 0.42764 to 0.42930, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 4/4 [==============================] - 0s 139ms/step - loss: 0.1953 - f1: 0.5199 - val_loss: 0.2365 - val_f1: 0.4293 - lr: 0.0010
# Epoch 11/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.1907 - f1: 0.5453
# Epoch 11: val_f1 improved from 0.42930 to 0.43386, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 4/4 [==============================] - 1s 143ms/step - loss: 0.1903 - f1: 0.5417 - val_loss: 0.2321 - val_f1: 0.4339 - lr: 0.0010
# Epoch 12/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.1850 - f1: 0.5582
# Epoch 12: val_f1 improved from 0.43386 to 0.44757, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 4/4 [==============================] - 1s 145ms/step - loss: 0.1856 - f1: 0.5575 - val_loss: 0.2238 - val_f1: 0.4476 - lr: 0.0010
# Epoch 13/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.1814 - f1: 0.5721
# Epoch 13: val_f1 improved from 0.44757 to 0.46466, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 4/4 [==============================] - 1s 150ms/step - loss: 0.1802 - f1: 0.5799 - val_loss: 0.2192 - val_f1: 0.4647 - lr: 0.0010
# Epoch 14/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.1756 - f1: 0.5803
# Epoch 14: val_f1 improved from 0.46466 to 0.46909, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 4/4 [==============================] - 1s 144ms/step - loss: 0.1761 - f1: 0.5756 - val_loss: 0.2175 - val_f1: 0.4691 - lr: 0.0010
# Epoch 15/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.1717 - f1: 0.5922
# Epoch 15: val_f1 did not improve from 0.46909
# 4/4 [==============================] - 0s 114ms/step - loss: 0.1712 - f1: 0.5953 - val_loss: 0.2171 - val_f1: 0.4622 - lr: 0.0010
# Epoch 16/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.1689 - f1: 0.5914
# Epoch 16: val_f1 did not improve from 0.46909
# 4/4 [==============================] - 0s 112ms/step - loss: 0.1692 - f1: 0.5860 - val_loss: 0.2140 - val_f1: 0.4596 - lr: 0.0010
# Epoch 17/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1649 - f1: 0.6057
# Epoch 17: val_f1 did not improve from 0.46909
# 4/4 [==============================] - 1s 159ms/step - loss: 0.1649 - f1: 0.6057 - val_loss: 0.2117 - val_f1: 0.4672 - lr: 0.0010
# Epoch 18/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.1605 - f1: 0.6087
# Epoch 18: val_f1 improved from 0.46909 to 0.47249, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 4/4 [==============================] - 1s 154ms/step - loss: 0.1598 - f1: 0.6183 - val_loss: 0.2110 - val_f1: 0.4725 - lr: 0.0010
# Epoch 19/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.1538 - f1: 0.6293
# Epoch 19: val_f1 did not improve from 0.47249
# 4/4 [==============================] - 0s 116ms/step - loss: 0.1547 - f1: 0.6216 - val_loss: 0.2106 - val_f1: 0.4723 - lr: 0.0010
# Epoch 20/20
# 3/4 [=====================>........] - ETA: 0s - loss: 0.1521 - f1: 0.6277
# Epoch 20: val_f1 improved from 0.47249 to 0.47708, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 4/4 [==============================] - 0s 135ms/step - loss: 0.1522 - f1: 0.6260 - val_loss: 0.2074 - val_f1: 0.4771 - lr: 0.0010
# 9/9 [==============================] - 2s 30ms/step
# (263, 107, 5)
# input_shape = (None, 50) | output_units = 5
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, 50)]        0
#
#  batch_normalization (BatchN  (None, None, 50)         200
#  ormalization)
#
#  simple_rnn (SimpleRNN)      (None, None, 100)         15100
#
#  batch_normalization_1 (Batc  (None, None, 100)        400
#  hNormalization)
#
#  dense (Dense)               (None, None, 5)           505
#
# =================================================================
# Total params: 16,205
# Trainable params: 15,905
# Non-trainable params: 300
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - ETA: 0s - loss: 0.3096 - f1: 0.2779
# Epoch 1: val_f1 improved from -inf to 0.40481, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 2/2 [==============================] - 5s 878ms/step - loss: 0.3096 - f1: 0.2779 - val_loss: 0.3259 - val_f1: 0.4048 - lr: 0.0010
# Epoch 2/20
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2851 - f1: 0.3089
# Epoch 2: val_f1 improved from 0.40481 to 0.40640, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 2/2 [==============================] - 0s 321ms/step - loss: 0.2814 - f1: 0.3321 - val_loss: 0.3201 - val_f1: 0.4064 - lr: 0.0010
# Epoch 3/20
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2683 - f1: 0.3489
# Epoch 3: val_f1 improved from 0.40640 to 0.41062, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 2/2 [==============================] - 0s 335ms/step - loss: 0.2681 - f1: 0.3579 - val_loss: 0.3097 - val_f1: 0.4106 - lr: 0.0010
# Epoch 4/20
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2551 - f1: 0.3855
# Epoch 4: val_f1 did not improve from 0.41062
# 2/2 [==============================] - 0s 244ms/step - loss: 0.2572 - f1: 0.3672 - val_loss: 0.3066 - val_f1: 0.4075 - lr: 0.0010
# Epoch 5/20
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2463 - f1: 0.4048
# Epoch 5: val_f1 did not improve from 0.41062
# 2/2 [==============================] - 0s 247ms/step - loss: 0.2467 - f1: 0.3982 - val_loss: 0.3009 - val_f1: 0.4068 - lr: 0.0010
# Epoch 6/20
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2399 - f1: 0.4242
# Epoch 6: val_f1 did not improve from 0.41062
# 2/2 [==============================] - 0s 235ms/step - loss: 0.2387 - f1: 0.4317 - val_loss: 0.2985 - val_f1: 0.4053 - lr: 0.0010
# Epoch 7/20
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2304 - f1: 0.4510
# Epoch 7: val_f1 did not improve from 0.41062
# 2/2 [==============================] - 0s 244ms/step - loss: 0.2323 - f1: 0.4365 - val_loss: 0.2945 - val_f1: 0.4031 - lr: 0.0010
# Epoch 8/20
# 2/2 [==============================] - ETA: 0s - loss: 0.2260 - f1: 0.4526
# Epoch 8: val_f1 did not improve from 0.41062
# 2/2 [==============================] - 1s 414ms/step - loss: 0.2260 - f1: 0.4526 - val_loss: 0.2912 - val_f1: 0.4019 - lr: 0.0010
# Epoch 9/20
# 2/2 [==============================] - ETA: 0s - loss: 0.2226 - f1: 0.4744
# Epoch 9: val_f1 did not improve from 0.41062
# 2/2 [==============================] - 0s 310ms/step - loss: 0.2226 - f1: 0.4744 - val_loss: 0.2903 - val_f1: 0.4007 - lr: 0.0010
# Epoch 10/20
# 2/2 [==============================] - ETA: 0s - loss: 0.2208 - f1: 0.4637
# Epoch 10: val_f1 did not improve from 0.41062
# 2/2 [==============================] - 0s 269ms/step - loss: 0.2208 - f1: 0.4637 - val_loss: 0.2896 - val_f1: 0.3996 - lr: 0.0010
# Epoch 11/20
# 2/2 [==============================] - ETA: 0s - loss: 0.2184 - f1: 0.4796
# Epoch 11: val_f1 did not improve from 0.41062
# 2/2 [==============================] - 0s 248ms/step - loss: 0.2184 - f1: 0.4796 - val_loss: 0.2885 - val_f1: 0.4000 - lr: 0.0010
# Epoch 12/20
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2108 - f1: 0.5053
# Epoch 12: val_f1 did not improve from 0.41062
# 2/2 [==============================] - 0s 244ms/step - loss: 0.2129 - f1: 0.4763 - val_loss: 0.2872 - val_f1: 0.4007 - lr: 0.0010
# Epoch 13/20
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2069 - f1: 0.5169
# Epoch 13: val_f1 did not improve from 0.41062
# 2/2 [==============================] - 0s 243ms/step - loss: 0.2085 - f1: 0.4803 - val_loss: 0.2851 - val_f1: 0.4005 - lr: 0.0010
# Epoch 14/20
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2051 - f1: 0.5155
# Epoch 14: val_f1 did not improve from 0.41062
# 2/2 [==============================] - 0s 235ms/step - loss: 0.2069 - f1: 0.4942 - val_loss: 0.2836 - val_f1: 0.4013 - lr: 0.0010
# Epoch 15/20
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1973 - f1: 0.5418
# Epoch 15: val_f1 did not improve from 0.41062
# 2/2 [==============================] - 0s 244ms/step - loss: 0.2029 - f1: 0.4752 - val_loss: 0.2810 - val_f1: 0.4019 - lr: 0.0010
# Epoch 16/20
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1967 - f1: 0.5388
# Epoch 16: val_f1 did not improve from 0.41062
# 2/2 [==============================] - 0s 233ms/step - loss: 0.1972 - f1: 0.5272 - val_loss: 0.2780 - val_f1: 0.4006 - lr: 0.0010
# Epoch 17/20
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1957 - f1: 0.5393
# Epoch 17: val_f1 did not improve from 0.41062
# 2/2 [==============================] - 0s 240ms/step - loss: 0.1939 - f1: 0.5559 - val_loss: 0.2754 - val_f1: 0.3997 - lr: 0.0010
# Epoch 18/20
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1906 - f1: 0.5617
# Epoch 18: val_f1 did not improve from 0.41062
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
# 2/2 [==============================] - 0s 246ms/step - loss: 0.1916 - f1: 0.5427 - val_loss: 0.2736 - val_f1: 0.3974 - lr: 0.0010
# Epoch 19/20
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1906 - f1: 0.5575
# Epoch 19: val_f1 did not improve from 0.41062
# 2/2 [==============================] - 0s 247ms/step - loss: 0.1905 - f1: 0.5616 - val_loss: 0.2716 - val_f1: 0.3946 - lr: 9.0000e-04
# Epoch 20/20
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1868 - f1: 0.5551
# Epoch 20: val_f1 did not improve from 0.41062
# 2/2 [==============================] - 0s 241ms/step - loss: 0.1880 - f1: 0.5718 - val_loss: 0.2703 - val_f1: 0.3909 - lr: 9.0000e-04
# 9/9 [==============================] - 1s 24ms/step
# (263, 107, 5)
# Load and train SimpleRNN Done!
# input_shape = (None, 50) | output_units = 5
# Model: "model_LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, 50)]        0
#
#  batch_normalization (BatchN  (None, None, 50)         200
#  ormalization)
#
#  lstm (LSTM)                 (None, None, 100)         60400
#
#  lstm_1 (LSTM)               (None, None, 100)         80400
#
#  lstm_2 (LSTM)               (None, None, 100)         80400
#
#  lstm_3 (LSTM)               (None, None, 100)         80400
#
#  dense (Dense)               (None, None, 256)         25856
#
#  batch_normalization_1 (Batc  (None, None, 256)        1024
#  hNormalization)
#
#  dropout (Dropout)           (None, None, 256)         0
#
#  dense_1 (Dense)             (None, None, 5)           1285
#
# =================================================================
# Total params: 329,965
# Trainable params: 329,353
# Non-trainable params: 612
# _________________________________________________________________
# Epoch 1/30
# 7/7 [==============================] - ETA: 0s - loss: 1.8897 - f1: 0.0851
# Epoch 1: val_f1 improved from -inf to 0.00000, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 7/7 [==============================] - 25s 1s/step - loss: 1.8897 - f1: 0.0851 - val_loss: 1.5063 - val_f1: 0.0000e+00 - lr: 0.0010
# Epoch 2/30
# 7/7 [==============================] - ETA: 0s - loss: 1.5268 - f1: 0.0231
# Epoch 2: val_f1 did not improve from 0.00000
# 7/7 [==============================] - 7s 964ms/step - loss: 1.5268 - f1: 0.0231 - val_loss: 1.4014 - val_f1: 0.0000e+00 - lr: 0.0010
# Epoch 3/30
# 7/7 [==============================] - ETA: 0s - loss: 1.3419 - f1: 0.0021
# Epoch 3: val_f1 did not improve from 0.00000
# 7/7 [==============================] - 6s 909ms/step - loss: 1.3419 - f1: 0.0021 - val_loss: 1.2736 - val_f1: 0.0000e+00 - lr: 0.0010
# Epoch 4/30
# 7/7 [==============================] - ETA: 0s - loss: 1.1803 - f1: 0.0019
# Epoch 4: val_f1 did not improve from 0.00000
# 7/7 [==============================] - 6s 831ms/step - loss: 1.1803 - f1: 0.0019 - val_loss: 1.1317 - val_f1: 0.0000e+00 - lr: 0.0010
# Epoch 5/30
# 7/7 [==============================] - ETA: 0s - loss: 1.0116 - f1: 0.0046
# Epoch 5: val_f1 did not improve from 0.00000
# 7/7 [==============================] - 5s 789ms/step - loss: 1.0116 - f1: 0.0046 - val_loss: 0.9753 - val_f1: 0.0000e+00 - lr: 0.0010
# Epoch 6/30
# 7/7 [==============================] - ETA: 0s - loss: 0.8296 - f1: 0.1499
# Epoch 6: val_f1 did not improve from 0.00000
# 7/7 [==============================] - 5s 784ms/step - loss: 0.8296 - f1: 0.1499 - val_loss: 0.8133 - val_f1: 0.0000e+00 - lr: 0.0010
# Epoch 7/30
# 7/7 [==============================] - ETA: 0s - loss: 0.6446 - f1: 0.8335
# Epoch 7: val_f1 improved from 0.00000 to 0.94831, saving model to ../models/weights_best_model\best_model_rnn_2.hdf5
# 7/7 [==============================] - 6s 815ms/step - loss: 0.6446 - f1: 0.8335 - val_loss: 0.6577 - val_f1: 0.9483 - lr: 0.0010
# Epoch 8/30
# 7/7 [==============================] - ETA: 0s - loss: 0.4738 - f1: 0.9990
# Epoch 8: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 6s 822ms/step - loss: 0.4738 - f1: 0.9990 - val_loss: 0.5280 - val_f1: 0.9483 - lr: 0.0010
# Epoch 9/30
# 7/7 [==============================] - ETA: 0s - loss: 0.3328 - f1: 1.0000
# Epoch 9: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 6s 916ms/step - loss: 0.3328 - f1: 1.0000 - val_loss: 0.4348 - val_f1: 0.9483 - lr: 0.0010
# Epoch 10/30
# 7/7 [==============================] - ETA: 0s - loss: 0.2290 - f1: 1.0000
# Epoch 10: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 6s 774ms/step - loss: 0.2290 - f1: 1.0000 - val_loss: 0.3774 - val_f1: 0.9483 - lr: 0.0010
# Epoch 11/30
# 7/7 [==============================] - ETA: 0s - loss: 0.1584 - f1: 1.0000
# Epoch 11: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 6s 787ms/step - loss: 0.1584 - f1: 1.0000 - val_loss: 0.3467 - val_f1: 0.9483 - lr: 0.0010
# Epoch 12/30
# 7/7 [==============================] - ETA: 0s - loss: 0.1125 - f1: 1.0000
# Epoch 12: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 5s 783ms/step - loss: 0.1125 - f1: 1.0000 - val_loss: 0.3328 - val_f1: 0.9483 - lr: 0.0010
# Epoch 13/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0836 - f1: 1.0000
# Epoch 13: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 6s 802ms/step - loss: 0.0836 - f1: 1.0000 - val_loss: 0.3285 - val_f1: 0.9483 - lr: 0.0010
# Epoch 14/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0642 - f1: 1.0000
# Epoch 14: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 5s 770ms/step - loss: 0.0642 - f1: 1.0000 - val_loss: 0.3292 - val_f1: 0.9483 - lr: 0.0010
# Epoch 15/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0512 - f1: 1.0000
# Epoch 15: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 5s 774ms/step - loss: 0.0512 - f1: 1.0000 - val_loss: 0.3324 - val_f1: 0.9483 - lr: 0.0010
# Epoch 16/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0423 - f1: 1.0000
# Epoch 16: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 5s 774ms/step - loss: 0.0423 - f1: 1.0000 - val_loss: 0.3368 - val_f1: 0.9483 - lr: 0.0010
# Epoch 17/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0355 - f1: 1.0000
# Epoch 17: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 5s 771ms/step - loss: 0.0355 - f1: 1.0000 - val_loss: 0.3416 - val_f1: 0.9483 - lr: 0.0010
# Epoch 18/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0307 - f1: 1.0000
# Epoch 18: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 5s 780ms/step - loss: 0.0307 - f1: 1.0000 - val_loss: 0.3465 - val_f1: 0.9483 - lr: 0.0010
# Epoch 19/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0267 - f1: 1.0000
# Epoch 19: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 6s 807ms/step - loss: 0.0267 - f1: 1.0000 - val_loss: 0.3515 - val_f1: 0.9483 - lr: 0.0010
# Epoch 20/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0236 - f1: 1.0000
# Epoch 20: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 5s 779ms/step - loss: 0.0236 - f1: 1.0000 - val_loss: 0.3563 - val_f1: 0.9483 - lr: 0.0010
# Epoch 21/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0211 - f1: 1.0000
# Epoch 21: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 5s 771ms/step - loss: 0.0211 - f1: 1.0000 - val_loss: 0.3611 - val_f1: 0.9483 - lr: 0.0010
# Epoch 22/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0190 - f1: 1.0000
# Epoch 22: val_f1 did not improve from 0.94831
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
# 7/7 [==============================] - 5s 775ms/step - loss: 0.0190 - f1: 1.0000 - val_loss: 0.3657 - val_f1: 0.9483 - lr: 0.0010
# Epoch 23/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0173 - f1: 1.0000
# Epoch 23: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 6s 790ms/step - loss: 0.0173 - f1: 1.0000 - val_loss: 0.3697 - val_f1: 0.9483 - lr: 9.0000e-04
# Epoch 24/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0159 - f1: 1.0000
# Epoch 24: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 5s 771ms/step - loss: 0.0159 - f1: 1.0000 - val_loss: 0.3736 - val_f1: 0.9483 - lr: 9.0000e-04
# Epoch 25/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0147 - f1: 1.0000
# Epoch 25: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 6s 804ms/step - loss: 0.0147 - f1: 1.0000 - val_loss: 0.3775 - val_f1: 0.9483 - lr: 9.0000e-04
# Epoch 26/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0136 - f1: 1.0000
# Epoch 26: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 5s 782ms/step - loss: 0.0136 - f1: 1.0000 - val_loss: 0.3812 - val_f1: 0.9483 - lr: 9.0000e-04
# Epoch 27/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0127 - f1: 1.0000
# Epoch 27: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 6s 848ms/step - loss: 0.0127 - f1: 1.0000 - val_loss: 0.3848 - val_f1: 0.9483 - lr: 9.0000e-04
# Epoch 28/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0118 - f1: 1.0000
# Epoch 28: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 5s 774ms/step - loss: 0.0118 - f1: 1.0000 - val_loss: 0.3883 - val_f1: 0.9483 - lr: 9.0000e-04
# Epoch 29/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0110 - f1: 1.0000
# Epoch 29: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 5s 769ms/step - loss: 0.0110 - f1: 1.0000 - val_loss: 0.3918 - val_f1: 0.9483 - lr: 9.0000e-04
# Epoch 30/30
# 7/7 [==============================] - ETA: 0s - loss: 0.0104 - f1: 1.0000
# Epoch 30: val_f1 did not improve from 0.94831
# 7/7 [==============================] - 5s 771ms/step - loss: 0.0104 - f1: 1.0000 - val_loss: 0.3951 - val_f1: 0.9483 - lr: 9.0000e-04
# Load and train SimpleRNN Done!
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model LSTM saved!
