# %% [markdown]
# # Read data

# %%
import mne
import numpy as np
import pandas as pd
import pickle
# %matplotlib widget
# import seaborn as sns
from matplotlib import pyplot as plt
import tensorflow as tf
# Out:
# 2022-10-05 15:27:47.812571: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-10-05 15:27:47.860033: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-05 15:27:47.860061: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
mounts = {
    1 : {
        'path_X_train' : './X_train_1.npy',
        'path_y_train' : './y_train_1.npy',
        'path_X_test_dataset' : './X_test_dataset_1.pkl',
    },
    2 : {
        'path_X_train' : './X_train_2.npy',
        'path_y_train' : './y_train_2.npy',
        'path_X_test_dataset' : './X_test_dataset_2.pkl',
    },
    3 : {
        'path_X_train' : './X_train_3.npy',
        'path_y_train' : './y_train_3.npy',
        'path_X_test_dataset' : './X_test_dataset_3.pkl',
    }
}

# %%
for mount_name, mount in mounts.items():
    mount['X_train'] = np.load(mount['path_X_train'])
    mount['y_train'] = np.load(mount['path_y_train'])
    with open(mount['path_X_test_dataset'], 'rb') as f:
        mount['X_test_dataset'] = pickle.load(f)
    print(len(mount['X_test_dataset']))
# Out:
# 899
# 855
# 861

# %%
y_test = pd.read_csv('./sample_submission.csv')

y_test[['subject_id', 'sample', 'timestep']] = (
    y_test['subject_id-sample-timestep']
    .str.split('-', 2, expand=True)
    .astype(int)
)
y_test

print(y_test.shape)
y_test.head()
# y_test.set_index(['subject_id', 'sample'])
# Out:
# (471610, 5)
#   subject_id-sample-timestep  class  subject_id  sample  timestep
# 0                      1-0-0      4           1       0         0
# 1                      1-0-1      2           1       0         1
# 2                      1-0-2      0           1       0         2
# 3                      1-0-3      0           1       0         3
# 4                      1-0-4      3           1       0         4

# %%
y_test.groupby(['subject_id'])['sample'].nunique()
# Out:
# subject_id
# 1    899
# 2    855
# 3    861
# Name: sample, dtype: int64

# %%
for mount_name, mount in mounts.items():
    X_train = mount['X_train']
    y_train = mount['y_train']
    
    events = np.where(np.abs(np.diff(y_train)) > 0)[0]
    
    fig, axx = plt.subplots(2, 1, sharex=True, figsize=(12, 5))
    plt.sca(axx[0])
    plt.plot(X_train, lw=0.5)
    plt.title('X_train')
    yl = plt.ylim()
    plt.vlines(events, *yl, color='r', lw=0.5, alpha=0.5)
    
    plt.sca(axx[1])
    plt.plot(y_train, lw=0.5)
    plt.title('y_train')
    yl = plt.ylim()
    plt.vlines(events, *yl, color='r', lw=0.5, alpha=0.5)
    plt.yticks(
        np.arange(-1, 5),
        ['Bad data', 'Open', 'Pistol', 'Thumb', 'OK', 'Grab']
    )
    plt.grid(axis='y')
    
    plt.suptitle(f"{mount_name}")
    plt.tight_layout()
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
SFREQ = 1000.0 / 33

for mount_name, mount in mounts.items():
    X_train = mount['X_train']
    y_train = mount['y_train']
    
    raw = mne.io.RawArray(
        data=X_train.T,
        info=mne.create_info(
            ch_names=list(np.arange(50).astype(str)),
            sfreq=SFREQ,
            ch_types='eeg'
        )
    )
    raw_y = mne.io.RawArray(
        data=y_train.reshape(1,-1),
        info=mne.create_info(
            ch_names=['y'],
            sfreq=SFREQ,
            ch_types='misc'
        )
    )
    raw = raw.add_channels([raw_y])
    
    mount['raw'] = raw
# Out:
# Creating RawArray with float64 data, n_channels=50, n_times=24030
#     Range : 0 ... 24029 =      0.000 ...   792.957 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=24030
#     Range : 0 ... 24029 =      0.000 ...   792.957 secs
# Ready.
# Creating RawArray with float64 data, n_channels=50, n_times=23202
#     Range : 0 ... 23201 =      0.000 ...   765.633 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=23202
#     Range : 0 ... 23201 =      0.000 ...   765.633 secs
# Ready.
# Creating RawArray with float64 data, n_channels=50, n_times=23177
#     Range : 0 ... 23176 =      0.000 ...   764.808 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=23177
#     Range : 0 ... 23176 =      0.000 ...   764.808 secs
# Ready.

# %%
for mount_name, mount in mounts.items():
    raw = mount['raw']
    y_train = mount['y_train']
    
    events = np.where(np.abs(np.diff(y_train)) > 0)[0]
    
    events = np.stack([
        events,
        np.zeros_like(events),
        np.zeros_like(events)
    ], axis=1)
    
    epochs = mne.Epochs(
        raw,
        events=events,
        tmin=-1,
        tmax=1 * 2.5,
        preload=True,
        baseline=None,
        picks='all'
    )
    
    X_train_nn = epochs.copy().pick_types(eeg =True)._data.swapaxes(1, 2)
    y_train_nn = epochs.copy().pick_types(misc=True)._data.swapaxes(1, 2)
    y_train_nn = tf.keras.utils.to_categorical(y_train_nn)
    
    mount['X_train_nn'] = X_train_nn
    mount['y_train_nn'] = y_train_nn

    print(X_train_nn.shape, y_train_nn.shape)
# Out:
# Not setting metadata
# 277 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 277 events and 107 original time points ...
# 1 bad epochs dropped
# (276, 107, 50) (276, 107, 5)
# Not setting metadata
# 264 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 264 events and 107 original time points ...
# 1 bad epochs dropped
# (263, 107, 50) (263, 107, 5)
# Not setting metadata
# 268 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 268 events and 107 original time points ...
# 1 bad epochs dropped
# (267, 107, 50) (267, 107, 5)

# %% [markdown]
# # Model architecture

# %%
_, n_timesteps, n_channels = X_train_nn.shape
output_units = y_train_nn.shape[-1]
print(f"input_shape = {(n_timesteps, n_channels)} | output_units = {output_units}")

input_channels = x = tf.keras.layers.Input(shape=(n_timesteps, n_channels))

x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.SimpleRNN(
    units=100,
    return_sequences=True,
    recurrent_regularizer=tf.keras.regularizers.L1L2(l1=1e-3, l2=1e-2),
)(x)
output = tf.keras.layers.Dense(units=output_units, activation='sigmoid')(x)

model = tf.keras.Model(
    inputs=input_channels,
    outputs=output,
    name="Model"
)

model.summary()
# Out:
# input_shape = (107, 50) | output_units = 5
# Model: "Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 107, 50)]         0
#
#  batch_normalization_5 (Batc  (None, 107, 50)          200
#  hNormalization)
#
#  simple_rnn_2 (SimpleRNN)    (None, 107, 100)          15100
#
#  dense_3 (Dense)             (None, 107, 5)            505
#
# =================================================================
# Total params: 15,805
# Trainable params: 15,705
# Non-trainable params: 100
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## Model train

# %%
from tensorflow.keras.metrics import Precision, Recall


for mount_name, mount in mounts.items():
    X_train_nn = mount['X_train_nn']
    y_train_nn = mount['y_train_nn']
    
    m = tf.keras.models.clone_model(model)
    m.compile(
        loss="mean_squared_error",
        metrics=[Precision(), Recall()],
        optimizer=tf.keras.optimizers.Adam(),
    )
    
    history = m.fit(
        X_train_nn,
        y_train_nn, 
        epochs=300,
        verbose=1,
    )
    
    y_pred_train_nn = m.predict(X_train_nn)
    print(y_pred_train_nn.shape)
    
    mount['model'] = m
    mount['y_pred_train_nn'] = y_pred_train_nn
# Out:
# Epoch 1/300
# 9/9 [==============================] - 1s 15ms/step - loss: 1.9523 - precision_6: 0.2844 - recall_6: 0.6759
# Epoch 2/300
# 9/9 [==============================] - 0s 14ms/step - loss: 1.7085 - precision_6: 0.3669 - recall_6: 0.7551
# Epoch 3/300
# 9/9 [==============================] - 0s 14ms/step - loss: 1.4971 - precision_6: 0.4318 - recall_6: 0.7668
# Epoch 4/300
# 9/9 [==============================] - 0s 14ms/step - loss: 1.3116 - precision_6: 0.5054 - recall_6: 0.7590
# Epoch 5/300
# 9/9 [==============================] - 0s 15ms/step - loss: 1.1470 - precision_6: 0.5891 - recall_6: 0.7383
# Epoch 6/300
# 9/9 [==============================] - 0s 15ms/step - loss: 1.0051 - precision_6: 0.6443 - recall_6: 0.7282
# Epoch 7/300
# 9/9 [==============================] - 0s 13ms/step - loss: 0.8816 - precision_6: 0.6891 - recall_6: 0.7173
# Epoch 8/300
# 9/9 [==============================] - 0s 14ms/step - loss: 0.7743 - precision_6: 0.7135 - recall_6: 0.7109
# Epoch 9/300
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6826 - precision_6: 0.7284 - recall_6: 0.7052
# Epoch 10/300
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6019 - precision_6: 0.7395 - recall_6: 0.7058
# Epoch 11/300
# 9/9 [==============================] - 0s 15ms/step - loss: 0.5313 - precision_6: 0.7466 - recall_6: 0.7146
# Epoch 12/300
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4705 - precision_6: 0.7498 - recall_6: 0.7166
# Epoch 13/300
# 9/9 [==============================] - 0s 15ms/step - loss: 0.4179 - precision_6: 0.7516 - recall_6: 0.7215
# Epoch 14/300
# 9/9 [==============================] - 0s 14ms/step - loss: 0.3713 - precision_6: 0.7554 - recall_6: 0.7208
# Epoch 15/300
# 9/9 [==============================] - 0s 14ms/step - loss: 0.3313 - precision_6: 0.7590 - recall_6: 0.7257
# Epoch 16/300
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2959 - precision_6: 0.7613 - recall_6: 0.7271
# Epoch 17/300
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2660 - precision_6: 0.7632 - recall_6: 0.7264
# Epoch 18/300
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2390 - precision_6: 0.7664 - recall_6: 0.7292
# Epoch 19/300
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2160 - precision_6: 0.7690 - recall_6: 0.7309
# Epoch 20/300
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1953 - precision_6: 0.7735 - recall_6: 0.7331
# Epoch 21/300
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1790 - precision_6: 0.7692 - recall_6: 0.7300
# Epoch 22/300
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1637 - precision_6: 0.7761 - recall_6: 0.7314
# Epoch 23/300
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1503 - precision_6: 0.7730 - recall_6: 0.7304
# Epoch 24/300
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1383 - precision_6: 0.7804 - recall_6: 0.7329
# Epoch 25/300
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1300 - precision_6: 0.7763 - recall_6: 0.7350
# Epoch 26/300
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1197 - precision_6: 0.7812 - recall_6: 0.7361
# Epoch 27/300
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1126 - precision_6: 0.7831 - recall_6: 0.7394
# Epoch 28/300
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1065 - precision_6: 0.7859 - recall_6: 0.7412
# Epoch 29/300
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1014 - precision_6: 0.7897 - recall_6: 0.7381
# Epoch 30/300
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0963 - precision_6: 0.7843 - recall_6: 0.7435
# Epoch 31/300
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0931 - precision_6: 0.7838 - recall_6: 0.7425
# Epoch 32/300
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0891 - precision_6: 0.7916 - recall_6: 0.7416
# Epoch 33/300
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0854 - precision_6: 0.7957 - recall_6: 0.7486
# Epoch 34/300
# 9/9 [==============================] - 0s 15ms/step - loss: 0.
300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0482 - precision_6: 0.8749 - recall_6: 0.8408
# Epoch 290/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0487 - precision_6: 0.8725 - recall_6: 0.8430
# Epoch 291/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0481 - precision_6: 0.8771 - recall_6: 0.8434
# Epoch 292/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0474 - precision_6: 0.8802 - recall_6: 0.8428
# Epoch 293/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0482 - precision_6: 0.8765 - recall_6: 0.8436
# Epoch 294/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0470 - precision_6: 0.8752 - recall_6: 0.8490
# Epoch 295/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0473 - precision_6: 0.8802 - recall_6: 0.8417
# Epoch 296/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0478 - precision_6: 0.8720 - recall_6: 0.8445
# Epoch 297/300
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0475 - precision_6: 0.8768 - recall_6: 0.8460
# Epoch 298/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0466 - precision_6: 0.8802 - recall_6: 0.8461
# Epoch 299/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0473 - precision_6: 0.8769 - recall_6: 0.8461
# Epoch 300/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0495 - precision_6: 0.8726 - recall_6: 0.8366
# 9/9 [==============================] - 0s 5ms/step
# (276, 107, 5)
# Epoch 1/300
# 9/9 [==============================] - 1s 14ms/step - loss: 1.9830 - precision_7: 0.1879 - recall_7: 0.4257
# Epoch 2/300
# 9/9 [==============================] - 0s 14ms/step - loss: 1.7367 - precision_7: 0.2726 - recall_7: 0.4906
# Epoch 3/300
# 9/9 [==============================] - 0s 17ms/step - loss: 1.5267 - precision_7: 0.3726 - recall_7: 0.5173
# Epoch 4/300
# 9/9 [==============================] - 0s 17ms/step - loss: 1.3434 - precision_7: 0.4633 - recall_7: 0.5351
# Epoch 5/300
# 9/9 [==============================] - 0s 19ms/step - loss: 1.1834 - precision_7: 0.5235 - recall_7: 0.5051
# Epoch 6/300
# 9/9 [==============================] - 0s 19ms/step - loss: 1.0437 - precision_7: 0.5658 - recall_7: 0.5128
# Epoch 7/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.9224 - precision_7: 0.6035 - recall_7: 0.4992
# Epoch 8/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.8159 - precision_7: 0.6350 - recall_7: 0.4915
# Epoch 9/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.7250 - precision_7: 0.6468 - recall_7: 0.4706
# Epoch 10/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6443 - precision_7: 0.6589 - recall_7: 0.4754
# Epoch 11/300
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5753 - precision_7: 0.6619 - recall_7: 0.4703
# Epoch 12/300
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5148 - precision_7: 0.6647 - recall_7: 0.4697
# Epoch 13/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4596 - precision_7: 0.6749 - recall_7: 0.4694
# Epoch 14/300
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4141 - precision_7: 0.6712 - recall_7: 0.4699
# Epoch 15/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3731 - precision_7: 0.6794 - recall_7: 0.4795
# Epoch 16/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3376 - precision_7: 0.6805 - recall_7: 0.4735
# Epoch 17/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3064 - precision_7: 0.6839 - recall_7: 0.4804
# Epoch 18/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2799 - precision_7: 0.6832 - recall_7: 0.4773
# Epoch 19/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2567 - precision_7: 0.6817 - recall_7: 0.4875
# Epoch 20/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2360 - precision_7: 0.6909 - recall_7: 0.4817
# Epoch 21/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2191 - precision_7: 0.6878 - recall_7: 0.4848
# Epoch 22/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2028 - precision_7: 0.6907 - recall_7: 0.4901
# Epoch 23/300
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1894 - precision_7: 0.6923 - recall_7: 0.4896
# Epoch 24/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1778 - precision_7: 0.6898 - recall_7: 0.4880
# Epoch 25/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1679 - precision_7: 0.6987 - recall_7: 0.4956
# Epoch 26/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1585 - precision_7: 0.6938 - recall_7: 0.4949
# Epoch 27/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1510 - precision_7: 0.6974 - recall_7: 0.4975
# Epoch 28/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1448 - precision_7: 0.6992 - recall_7: 0.5064
# Epoch 29/300
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1393 - precision_7: 0.7022 - recall_7: 0.4984
# Epoch 30/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1349 - precision_7: 0.6993 - recall_7: 0.5074
# Epoch 31/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1300 - precision_7: 0.7033 - recall_7: 0.5074
# Epoch 32/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1264 - precision_7: 0.7048 - recall_7: 0.5061
# Epoch 33/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1231 - precision_7: 0.7035 - recall_7: 0.5207
# Epoch 34/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1210 - precision_7: 0.6980 - recall_7: 0.5105
# Epoch 35/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1180 - precision_7: 0.7068 - recall_7: 0.5283
# Epoch 36/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1164 - precision_7: 0.7035 - recall_7: 0.5362
# Epoch 37/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1155 - precision_7: 0.7032 - recall_7: 0.5189
# Epoch 38/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1138 - precision_7: 0.7008 - recall_7: 0.5282
# Epoch 39/300
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1125 - precision_7: 0.7050 - recall_7: 0.5321
# Epoch 40/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1117 - precision_7: 0.7075 - recall_7: 0.5367
# Epoch 41/300
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1110 - precision_7: 0.6990 - recall_7: 0.5330
# Epoch 42/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1091 - precision_7: 0.7050 - recall_7: 0.5394
# Epoch 43/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1079 - precision_7: 0.7115 - recall_7: 0.5430
# Epoch 44/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1076 - precision_7: 0.7098 - recall_7: 0.5491
# Epoch 45/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1069 - precision_7: 0.7122 - recall_7: 0.5488
# Epoch 46/300
# 9/9 [==============================] - 0s 21ms/step - loss: 0.1068 - precision_7: 0.7122 - recall_7: 0.5537
# Epoch 47/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1056 - precision_7: 0.7154 - recall_7: 0.5588
# Epoch 48/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1071 - precision_7: 0.7092 - recall_7: 0.5637
# Epoch 49/300
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1060 - precision_7: 0.7088 - recall_7: 0.5617
# Epoch 50/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1043 - precision_7: 0.7199 - recall_7: 0.5615
# Epoch 51/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1038 - precision_7: 0.7208 - recall_7: 0.5560
# Epoch 52/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1041 - precision_7: 0.7178 - recall_7: 0.5623
# Epoch 53/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1029 - precision_7: 0.7231 - recall_7: 0.5751
# Epoch 54/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1030 - precision_7: 0.7163 - recall_7: 0.5832
# Epoch 55/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1029 - precision_7: 0.7240 - recall_7: 0.5702
# Epoch 56/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1035 - precision_7: 0.7157 - recall_7: 0.5655
# Epoch 57/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1026 - precision_7: 0.7234 - recall_7: 0.5817
# Epoch 58/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1024 - precision_7: 0.7243 - recall_7: 0.5772
# Epoch 59/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1021 - precision_7: 0.7254 - recall_7: 0.5735
# Epoch 60/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1022 - precision_7: 0.7230 - recall_7: 0.5692
# Epoch 61/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1017 - precision_7: 0.7222 - recall_7: 0.5735
# Epoch 62/300
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1005 - precision_7: 0.7237 - recall_7: 0.5892
# Epoch 63/300
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1031 - precision_7: 0.7171 - recall_7: 0.5716
# Epoch 64/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1022 - precision_7: 0.7174 - recall_7: 0.5851
# Epoch 65/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1014 - precision_7: 0.7239 - recall_7: 0.5804
# Epoch 66/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1017 - precision_7: 0.7228 - recall_7: 0.5770
# Epoch 67/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1012 - precision_7: 0.7237 - recall_7: 0.5854
# Epoch 68/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1008 - precision_7: 0.7193 - recall_7: 0.5849
# Epoch 69/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1000 - precision_7: 0.7304 - recall_7: 0.5886
# Epoch 70/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0999 - precision_7: 0.7284 - recall_7: 0.5885
# Epoch 71/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1000 - precision_7: 0.7248 - recall_7: 0.5913
# Epoch 72/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.1000 - precision_7: 0.7246 - recall_7: 0.5938
# Epoch 73/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1004 - precision_7: 0.7210 - recall_7: 0.5890
# Epoch 74/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0995 - precision_7: 0.7312 - recall_7: 0.5934
# Epoch 75/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0995 - precision_7: 0.7267 - recall_7: 0.5984
# Epoch 76/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0983 - precision_7: 0.7329 - recall_7: 0.6081
# Epoch 77/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0990 - precision_7: 0.7283 - recall_7: 0.5912
# Epoch 78/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0987 - precision_7: 0.7306 - recall_7: 0.6003
# Epoch 79/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0988 - precision_7: 0.7272 - recall_7: 0.6002
# Epoch 80/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0977 - precision_7: 0.7297 - recall_7: 0.6006
# Epoch 81/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0983 - precision_7: 0.7350 - recall_7: 0.6012
# Epoch 82/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0974 - precision_7: 0.7323 - recall_7: 0.6076
# Epoch 83/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0971 - precision_7: 0.7274 - recall_7: 0.6048
# Epoch 84/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0977 - precision_7: 0.7284 - recall_7: 0.6110
# Epoch 85/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0981 - precision_7: 0.7285 - recall_7: 0.5979
# Epoch 86/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0983 - precision_7: 0.7308 - recall_7: 0.6033
# Epoch 87/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0980 - precision_7: 0.7273 - recall_7: 0.6045
# Epoch 88/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0982 - precision_7: 0.7292 - recall_7: 0.6136
# Epoch 89/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0975 - precision_7: 0.7346 - recall_7: 0.6046
# Epoch 90/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0974 - precision_7: 0.7330 - recall_7: 0.6051
# Epoch 91/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0973 - precision_7: 0.7308 - recall_7: 0.6099
# Epoch 92/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0970 - precision_7: 0.7300 - recall_7: 0.6069
# Epoch 93/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0963 - precision_7: 0.7362 - recall_7: 0.6159
# Epoch 94/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0962 - precision_7: 0.7314 - recall_7: 0.6137
# Epoch 95/300
# ...
# Epoch 171/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0870 - precision_8: 0.7626 - recall_8: 0.6342
# Epoch 172/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0859 - precision_8: 0.7643 - recall_8: 0.6470
# Epoch 173/300
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0863 - precision_8: 0.7642 - recall_8: 0.6451
# Epoch 174/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0862 - precision_8: 0.7647 - recall_8: 0.6511
# Epoch 175/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0864 - precision_8: 0.7554 - recall_8: 0.6599
# Epoch 176/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0875 - precision_8: 0.7663 - recall_8: 0.6371
# Epoch 177/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0860 - precision_8: 0.7690 - recall_8: 0.6427
# Epoch 178/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0872 - precision_8: 0.7564 - recall_8: 0.6426
# Epoch 179/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0863 - precision_8: 0.7650 - recall_8: 0.6495
# Epoch 180/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0870 - precision_8: 0.7604 - recall_8: 0.6469
# Epoch 181/300
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0860 - precision_8: 0.7634 - recall_8: 0.6555
# Epoch 182/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0862 - precision_8: 0.7689 - recall_8: 0.6423
# Epoch 183/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0868 - precision_8: 0.7580 - recall_8: 0.6414
# Epoch 184/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0865 - precision_8: 0.7607 - recall_8: 0.6483
# Epoch 185/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0853 - precision_8: 0.7614 - recall_8: 0.6549
# Epoch 186/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0866 - precision_8: 0.7637 - recall_8: 0.6425
# Epoch 187/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0866 - precision_8: 0.7554 - recall_8: 0.6518
# Epoch 188/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0859 - precision_8: 0.7647 - recall_8: 0.6504
# Epoch 189/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0859 - precision_8: 0.7611 - recall_8: 0.6564
# Epoch 190/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0876 - precision_8: 0.7576 - recall_8: 0.6441
# Epoch 191/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0858 - precision_8: 0.7644 - recall_8: 0.6480
# Epoch 192/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0857 - precision_8: 0.7670 - recall_8: 0.6484
# Epoch 193/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0856 - precision_8: 0.7619 - recall_8: 0.6646
# Epoch 194/300
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0850 - precision_8: 0.7670 - recall_8: 0.6590
# Epoch 195/300
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0851 - precision_8: 0.7656 - recall_8: 0.6528
# Epoch 196/300
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0851 - precision_8: 0.7648 - recall_8: 0.6528
# Epoch 197/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0854 - precision_8: 0.7643 - recall_8: 0.6591
# Epoch 198/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0857 - precision_8: 0.7573 - recall_8: 0.6592
# Epoch 199/300
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0863 - precision_8: 0.7662 - recall_8: 0.6438
# Epoch 200/300
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0840 - precision_8: 0.7704 - recall_8: 0.6594
# Epoch 201/300
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0845 - precision_8: 0.7677 - recall_8: 0.6606
# Epoch 202/300
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0837 - precision_8: 0.7694 - recall_8: 0.6628
# Epoch 203/300
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0852 - precision_8: 0.7637 - recall_8: 0.6568
# Epoch 204/300
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0840 - precision_8: 0.7707 - recall_8: 0.6557
# Epoch 205/300
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0842 - precision_8: 0.7726 - recall_8: 0.6472
# Epoch 206/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0856 - precision_8: 0.7638 - recall_8: 0.6484
# Epoch 207/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0848 - precision_8: 0.7603 - recall_8: 0.6633
# Epoch 208/300
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0854 - precision_8: 0.7689 - recall_8: 0.6493
# Epoch 209/300
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0835 - precision_8: 0.7713 - recall_8: 0.6699
# Epoch 210/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0844 - precision_8: 0.7717 - recall_8: 0.6589
# Epoch 211/300
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0842 - precision_8: 0.7713 - recall_8: 0.6679
# Epoch 212/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0850 - precision_8: 0.7648 - recall_8: 0.6620
# Epoch 213/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0834 - precision_8: 0.7717 - recall_8: 0.6666
# Epoch 214/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0835 - precision_8: 0.7698 - recall_8: 0.6707
# Epoch 215/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0836 - precision_8: 0.7669 - recall_8: 0.6712
# Epoch 216/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0831 - precision_8: 0.7692 - recall_8: 0.6675
# Epoch 217/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0831 - precision_8: 0.7761 - recall_8: 0.6606
# Epoch 218/300
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0825 - precision_8: 0.7751 - recall_8: 0.6700
# Epoch 219/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0828 - precision_8: 0.7769 - recall_8: 0.6686
# Epoch 220/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0831 - precision_8: 0.7645 - recall_8: 0.6751
# Epoch 221/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0833 - precision_8: 0.7664 - recall_8: 0.6736
# Epoch 222/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0842 - precision_8: 0.7705 - recall_8: 0.6545
# Epoch 223/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0826 - precision_8: 0.7784 - recall_8: 0.6742
# Epoch 224/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0831 - precision_8: 0.7743 - recall_8: 0.6654
# Epoch 225/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0835 - precision_8: 0.7638 - recall_8: 0.6783
# Epoch 226/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0828 - precision_8: 0.7729 - recall_8: 0.6750
# Epoch 227/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0843 - precision_8: 0.7706 - recall_8: 0.6459
# Epoch 228/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0824 - precision_8: 0.7716 - recall_8: 0.6726
# Epoch 229/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0821 - precision_8: 0.7715 - recall_8: 0.6726
# Epoch 230/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0821 - precision_8: 0.7755 - recall_8: 0.6707
# Epoch 231/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0816 - precision_8: 0.7734 - recall_8: 0.6696
# Epoch 232/300
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0813 - precision_8: 0.7774 - recall_8: 0.6812
# Epoch 233/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0811 - precision_8: 0.7802 - recall_8: 0.6708
# Epoch 234/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0826 - precision_8: 0.7712 - recall_8: 0.6727
# Epoch 235/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0816 - precision_8: 0.7746 - recall_8: 0.6776
# Epoch 236/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0824 - precision_8: 0.7756 - recall_8: 0.6734
# Epoch 237/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0815 - precision_8: 0.7745 - recall_8: 0.6838
# Epoch 238/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0816 - precision_8: 0.7734 - recall_8: 0.6723
# Epoch 239/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0816 - precision_8: 0.7782 - recall_8: 0.6767
# Epoch 240/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0825 - precision_8: 0.7834 - recall_8: 0.6661
# Epoch 241/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0809 - precision_8: 0.7824 - recall_8: 0.6789
# Epoch 242/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0813 - precision_8: 0.7754 - recall_8: 0.6890
# Epoch 243/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0809 - precision_8: 0.7752 - recall_8: 0.6840
# Epoch 244/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0801 - precision_8: 0.7835 - recall_8: 0.6820
# Epoch 245/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0815 - precision_8: 0.7835 - recall_8: 0.6687
# Epoch 246/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0813 - precision_8: 0.7774 - recall_8: 0.6731
# Epoch 247/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0815 - precision_8: 0.7778 - recall_8: 0.6814
# Epoch 248/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0802 - precision_8: 0.7824 - recall_8: 0.6854
# Epoch 249/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0811 - precision_8: 0.7761 - recall_8: 0.6770
# Epoch 250/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0815 - precision_8: 0.7787 - recall_8: 0.6756
# Epoch 251/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0811 - precision_8: 0.7821 - recall_8: 0.6781
# Epoch 252/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0813 - precision_8: 0.7797 - recall_8: 0.6809
# Epoch 253/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0803 - precision_8: 0.7786 - recall_8: 0.6881
# Epoch 254/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0811 - precision_8: 0.7795 - recall_8: 0.6861
# Epoch 255/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0786 - precision_8: 0.7870 - recall_8: 0.6954
# Epoch 256/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0803 - precision_8: 0.7756 - recall_8: 0.6896
# Epoch 257/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0819 - precision_8: 0.7772 - recall_8: 0.6759
# Epoch 258/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0794 - precision_8: 0.7884 - recall_8: 0.6788
# Epoch 259/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0790 - precision_8: 0.7838 - recall_8: 0.6929
# Epoch 260/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0798 - precision_8: 0.7833 - recall_8: 0.6833
# Epoch 261/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0798 - precision_8: 0.7859 - recall_8: 0.6826
# Epoch 262/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0803 - precision_8: 0.7857 - recall_8: 0.6781
# Epoch 263/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0807 - precision_8: 0.7790 - recall_8: 0.6822
# Epoch 264/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0819 - precision_8: 0.7760 - recall_8: 0.6805
# Epoch 265/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0797 - precision_8: 0.7861 - recall_8: 0.6886
# Epoch 266/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0789 - precision_8: 0.7864 - recall_8: 0.6921
# Epoch 267/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0803 - precision_8: 0.7785 - recall_8: 0.6808
# Epoch 268/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0808 - precision_8: 0.7803 - recall_8: 0.6865
# Epoch 269/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0790 - precision_8: 0.7902 - recall_8: 0.6897
# Epoch 270/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0794 - precision_8: 0.7933 - recall_8: 0.6839
# Epoch 271/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0798 - precision_8: 0.7847 - recall_8: 0.6866
# Epoch 272/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0776 - precision_8: 0.7883 - recall_8: 0.7031
# Epoch 273/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0800 - precision_8: 0.7807 - recall_8: 0.6844
# Epoch 274/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0792 - precision_8: 0.7860 - recall_8: 0.6959
# Epoch 275/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0789 - precision_8: 0.7864 - recall_8: 0.6977
# Epoch 276/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0786 - precision_8: 0.7907 - recall_8: 0.6844
# Epoch 277/300
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0789 - precision_8: 0.7882 - recall_8: 0.6886
# Epoch 278/300
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0787 - precision_8: 0.7866 - recall_8: 0.7010
# Epoch 279/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0793 - precision_8: 0.7864 - recall_8: 0.6876
# Epoch 280/300
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0804 - precision_8: 0.7800 - recall_8: 0.6927
# Epoch 281/300
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0790 - precision_8: 0.7881 - recall_8: 0.6928
# Epoch 282/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0803 - precision_8: 0.7892 - recall_8: 0.6815
# Epoch 283/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0802 - precision_8: 0.7798 - recall_8: 0.6840
# Epoch 284/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0785 - precision_8: 0.7900 - recall_8: 0.7003
# Epoch 285/300
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0786 - precision_8: 0.7861 - recall_8: 0.6932
# Epoch 286/300
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0796 - precision_8: 0.7815 - recall_8: 0.6900
# Epoch 287/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0786 - precision_8: 0.7902 - recall_8: 0.6936
# Epoch 288/300
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0791 - precision_8: 0.7882 - recall_8: 0.6878
# Epoch 289/300
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0791 - precision_8: 0.7841 - recall_8: 0.6905
# Epoch 290/300
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0779 - precision_8: 0.7826 - recall_8: 0.7168
# Epoch 291/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0784 - precision_8: 0.7876 - recall_8: 0.7012
# Epoch 292/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0794 - precision_8: 0.7898 - recall_8: 0.6868
# Epoch 293/300
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0784 - precision_8: 0.7942 - recall_8: 0.6862
# Epoch 294/300
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0768 - precision_8: 0.7921 - recall_8: 0.7060
# Epoch 295/300
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0794 - precision_8: 0.7867 - recall_8: 0.6852
# Epoch 296/300
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0780 - precision_8: 0.7826 - recall_8: 0.6923
# Epoch 297/300
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0781 - precision_8: 0.7864 - recall_8: 0.6961
# Epoch 298/300
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0770 - precision_8: 0.7945 - recall_8: 0.7043
# Epoch 299/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0770 - precision_8: 0.8000 - recall_8: 0.6968
# Epoch 300/300
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0773 - precision_8: 0.7871 - recall_8: 0.6987
# 9/9 [==============================] - 0s 5ms/step
# (267, 107, 5)

# %% [markdown]
# ## Visualisation

# %%
i = 7

fig, axx = plt.subplots(4, 1, sharex=True, figsize=(10, 8))

axx[0].plot(X_train_nn[i])
axx[0].set_title('OMG')

axx[1].imshow(y_train_nn[i].T, origin="lower")
axx[1].set_aspect('auto')
axx[1].set_title('Class/Command')
axx[1].set_yticks(
    np.arange(5),
    ['Open', 'Pistol', 'Thumb', 'OK', 'Grab']
)

axx[2].imshow(y_pred_train_nn[i].T, origin="lower") # , vmin=-0.5, vmax=0.5
axx[2].set_aspect('auto')
axx[2].set_title('Model output')
axx[2].set_yticks(
    np.arange(5),
    ['Open', 'Pistol', 'Thumb', 'OK', 'Grab']
)

axx[3].plot(y_pred_train_nn[i].argmax(axis=-1))
axx[3].set_aspect('auto')
axx[3].set_title('Actual Gesture')
axx[3].set_yticks(
    np.arange(5),
    ['Open', 'Pistol', 'Thumb', 'OK', 'Grab']
)
axx[3].set_xlabel('Timestep')

plt.suptitle(f'Train {i}')
plt.tight_layout()
plt.gcf()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Look at `X_test_dataset`

# %%
for mount_name, mount in mounts.items():
    X_test_dataset = mount['X_test_dataset']
    print(f"subject {mount_name}")
    shapes, counts = np.unique(
        [arr.shape for arr in X_test_dataset],
        return_counts=True,
        axis=0
    )
    for shape, count in zip(shapes, counts):
        print(f"\tshape {tuple(shape)} appears {count} times.")
# Out:
# subject 1
# 	shape (50, 105) appears 303 times.
# 	shape (50, 181) appears 299 times.
# 	shape (50, 256) appears 297 times.
# subject 2
# 	shape (50, 105) appears 286 times.
# 	shape (50, 181) appears 285 times.
# 	shape (50, 256) appears 284 times.
# subject 3
# 	shape (50, 105) appears 291 times.
# 	shape (50, 181) appears 282 times.
# 	shape (50, 256) appears 288 times.

# %%
for mount_name, mount in mounts.items():
    X_test_dataset = mount['X_test_dataset']
    fig, axx = plt.subplots(3, 1, sharex=True, figsize=(12, 5))
    plt.sca(axx[0])
    plt.plot(X_test_dataset[3].T, lw=0.5)
    plt.title('Sample of length 105')
    
    plt.sca(axx[1])
    plt.plot(X_test_dataset[1].T, lw=0.5)
    plt.title('Sample of length 181')
    
    plt.sca(axx[2])
    plt.plot(X_test_dataset[8].T, lw=0.5)
    plt.title('Sample of length 256')
    
    plt.suptitle(f"Subject {mount_name}")
    plt.tight_layout()
    plt.show()
    
    break
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Predict test & submit

# %%
for mount_name, mount in mounts.items():
    m = mount['model']
    X_train_nn = mount['X_train_nn']
    X_test_dataset = mount['X_test_dataset']
    
    y_pred_test_nn = []
    for i in range(len(X_test_dataset)):
        X_test_i = np.expand_dims(X_test_dataset[i], axis=0).swapaxes(1, 2).astype(np.float64)
        y_pred_test_nn += [m.predict(X_test_i, verbose=0)]
        
    y_pred_test = [arr.argmax(axis=-1) for arr in y_pred_test_nn]
    
    print(len(y_pred_test))
    assert len(y_pred_test) == y_test.query("subject_id == @mount_name")['sample'].nunique()
    
    mount['y_pred_test_nn'] = y_pred_test_nn
    mount['y_pred_test'] = y_pred_test
# Out:
# 899
# 855
# 861

# %%
y_pred_test_res = []
for mount_name, mount in mounts.items():
    y_pred_test_res.extend(mount['y_pred_test'])
y_pred_test_res = np.concatenate(y_pred_test_res, axis=-1)[0]

assert y_pred_test_res.shape[0] == y_test.shape[0]

# %%
y_test_submit = y_test[['subject_id-sample-timestep', 'class']]
y_test_submit['class'] = y_pred_test_res
y_test_submit.to_csv('./y_test_submit_rnn_baseline.csv', index=False)

y_test_submit
# Out:
# /tmp/ipykernel_1802826/4054502539.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test_submit['class'] = y_pred_test_res
#        subject_id-sample-timestep  class
# 0                           1-0-0      0
# 1                           1-0-1      0
# 2                           1-0-2      0
# 3                           1-0-3      0
# 4                           1-0-4      0
# ...                           ...    ...
# 471605                  3-860-176      0
# 471606                  3-860-177      0
# 471607                  3-860-178      0
# 471608                  3-860-179      0
# 471609                  3-860-180      0
#
# [471610 rows x 2 columns]
